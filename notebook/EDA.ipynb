# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df =  pd.read_csv('data/stud.csv')

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
df['race_ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df['parental_level_of_education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
df['test_preparation_course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
df['Total_score'] = df['math_score']+df['reading_score'] + df['writing_score']

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
df['Average'] = df['Total_score']/3

# %%
df[(df['math_score'] == 100)  & (df['writing_score'] == 100) & (df['reading_score'] == 100)]
# Out:
#      gender race_ethnicity parental_level_of_education     lunch  \
# 458  female        group E           bachelor's degree  standard
# 916    male        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
#
#      Total_score  Average
# 458          300    100.0
# 916          300    100.0
# 962          300    100.0

# %%
df[(df['math_score'] <= 20)  & (df['writing_score'] <= 20) & (df['reading_score'] <= 20)]
# Out:
#     gender race_ethnicity parental_level_of_education         lunch  \
# 59  female        group C            some high school  free/reduced
#
#    test_preparation_course  math_score  reading_score  writing_score  \
# 59                    none           0             17             10
#
#     Total_score  Average
# 59           27      9.0

# %%
sns.histplot(data = df,x='Average',hue='gender')
# Out:
# <Axes: xlabel='Average', ylabel='Count'>

# %%
sns.countplot(data=df,x='parental_level_of_education',hue='gender')
plt.xticks(rotation=  45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, "bachelor's degree"),
#   Text(1, 0, 'some college'),
#   Text(2, 0, "master's degree"),
#   Text(3, 0, "associate's degree"),
#   Text(4, 0, 'high school'),
#   Text(5, 0, 'some high school')])

# %%
sns.kdeplot(data = df,x='Average',color='red',hue='gender')
# Out:
# <Axes: xlabel='Average', ylabel='Density'>

# %%
sns.countplot(data=df,x='test_preparation_course')
# Out:
# <Axes: xlabel='test_preparation_course', ylabel='count'>

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'Total_score', 'Average'],
#       dtype='object')

# %%
sns.pairplot(data=df,hue='test_preparation_course',x)

# %%
sns.kdeplot(data = df,x='Average',color='red',hue='test_preparation_course')
# Out:
# <Axes: xlabel='Average', ylabel='Density'>

# %%
df.to_csv('data/updated_stud.csv')
